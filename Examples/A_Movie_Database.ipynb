# %% [markdown]
# <div class="alert alert-block alert-success"><h1>Domain: movie</h1></div><br>
#
# <div><h3>Data Source</h3></div>
# Data used in this project are scraped from IMDB and Twitter<br>
# To further learn about SQL,__[Check this](https://en.wikipedia.org/wiki/SQL)__<br>
#
# <h3> Databases (including tools) I use for both parts</h3>
# <div><a id="section_ID">
#     <p>1.MySQL</p>
#     <p>2.phpMyAdmin</p>
#     <p>3.MongoDB</p>
#     <p>4.Studio 3T</p>
#     <p>3.Robo 3T</p>
#
#
# <h3>Some important parts regarding the project</h3>
# <ul>
#     <div style="color:blue"><li><b>1.ER-diagram</b></li><br></div>
#    ER-diagram represents the relationship between different entities in my database, down below is a ER-diagram of our project.<br>
# ![94400e9f914cd2ce3ee09a13d9dd1d3.png](attachment:94400e9f914cd2ce3ee09a13d9dd1d3.png)<br>
#     As showed in this ER-Diagram, every retangle represents a entity, and all those eclipses which are connected by a line are all attributes that we need in this database project,also, those prismatics are the relationship between different entities. One movie can be rated by multiple audiences, vise versa, that's why the relationship between them is N to N.<br><br>
#
#     <div style="color:blue"><li><b>2.Scraping Data from imdb</b></liv></div><br>
#    first,scrape data from imdb to see what kind of movie shots in the 10-year period.<br><br>
#
#     <ul>
#       <li>Install tweepy, and register yourself as a developer </li><br>
#       <li>Scrape data from twitter</li>
#     </ul>
#     <br> First, register yourself to get acquired to twitter API, after that ,your API key, API secret, Access token and Access token secret will be automatically generated.
# </ul>

# %%
import pymysql
import tweepy
import json
from dateutil import parser
import pandas as pd
import re
import pymysql
import sqlalchemy
import numpy as np  
import twitter 
from pandas.io import sql


import tweepy
import csv

consumer_key= 'uzHA74JKJ3woXVnXZBBMjt3PN'#'RC5aZYjVtp4vVZXTPyFsTAvQj'
consumer_secret= 'kTuWm8ltScWibokVSeLmAat5RZuti4mSyQF8g4IVrb95Xz8lFh'#'WzaNQnjW63rFiVQuIw6cDDbqfD909CG3g9gFgrpZZs3ORRItkT'
access_token= '4924562533-UIsWAAvLF8svY2RmDEpZKAlPGwq79p4kg2UeExc'#'963218364998078464-rlszyp5bDgBfEQXZXNqxNDyRW8G3VER'
access_token_secret= 'MNLUH1cQaiPDXprTJYJD4yNcGLdXh9FKvJ2QeLCd4KLgc'#'DpblUYvmh6Z1Wv1D49lihbNlHm7xIuVd4xRkPY0DTsL9x'

# %% [markdown]
# * After this is done, then scrape the data, I use hashtags such as "#movies", "#movienight","hollywood","#MyBestMovies" and so on to see.<br>

# %%
import csv
import json
import pandas as pd
import sys, getopt, pprint
from pymongo import MongoClient

csvfile = open('/Users/josef/Desktop/ttt/movienight.csv','r')
reader = csv.DictReader(csvfile)
mongo_client = MongoClient("localhost",27017)
db = mongo_client.movie
db.movienight.drop()
header = ["user_id", "time_zone", "created_at", "fav","retweet","text","tags"]

for each in reader:
    row = {}
    for field in header:
        row[field]=each[field]
        
    db.movienight.insert(row)

# %% [markdown]
# * Note that our final data is stored as different CSV file which We will be insert later

# %% [markdown]
# <h3>Insert data into both SQL and NoSQL</h3>
# <ul>
# <li>Create the database. From the MySQL command line, enter the command CREATE DATABASE <DATABASENAME>;. Replace <DATABASENAME> with the name of your database. It cannot include spaces.<br>
# In my project, I  create a database called movie, writting  CREATE DATABASE movie in the Mysql Command.<br><br>
# <div style="color:red"> Note: Commands do not have to be entered in upper-case.</div>
#
# <h3>About constraints</h3><br>
# All tables connected displayed in this picture has a primary key and a foreign key, and that is showed by the structure.<br>
# ![image.png](attachment:image.png)<br>
#
#
# Down below is the screenshots of my sql database,including indices, triggers,function and stored procedure. followed by queries. All of them is incuded as sql documents in the same directory.<br>
# ![1524682636%281%29.jpg](attachment:1524682636%281%29.jpg) <br>
#
# The screenshot is the partial operation on the data.<br>
# ![1524682784%281%29.jpg](attachment:1524682784%281%29.jpg)<br><br>

# %% [markdown]
# <h3>Now I need to mention that how I insert data into my table</h3>
#  Using phpMyAdmin.<br>
# <ul>
#      <div style="color:blue"><li>Use phpMyAdmin</li></div>
#     1.Open my phpMyAdmin, select the database and open the table I wanted to import my data into, then click the "import" button<br>
#     ![1524583286%281%29.jpg](attachment:1524583286%281%29.jpg)<br>
#     2.Choose the file then import.<br>
#     ![1524583500%281%29.jpg](attachment:1524583500%281%29.jpg)<br>
#     <div style="color:red">Notice:<br>
#         <li>For partial import, set the skip number into 1</li>
#         <li>For column names,enter the column title exactly the same as the name in your csv file, seperated by "," </li>
#     </div>
#     Click the "Go" <br>
#    So this the table<br>
#     ![1524583895%281%29.jpg](attachment:1524583895%281%29.jpg)
# </ul>

# %% [markdown]
# <h3>Insert data into MongoDB<h3>
# <ul>
#     <li>Open cmd to enter "mongod" to continue</li>
#     ![1524685593%281%29.jpg](attachment:1524685593%281%29.jpg)
#     <li>Open the GUI to connect to the database</li>
#     ![1524685753%281%29.jpg](attachment:1524685753%281%29.jpg)
#     <li>Open the cmd again to enter "mongo"</li>
#     ![1524685844%281%29.jpg](attachment:1524685844%281%29.jpg)<br>
#     <li>Import the data</li>
#     ![1524686007%281%29.jpg](attachment:1524686007%281%29.jpg)<br><br>
#    <b> Notice: the name behind "-d" is my database's name, then the name behind "c" is one specific table's name, then type the format of the file, followed by a path of the file,the rest is the common code.<b>
#
#
# </ul>

# %% [markdown]
# <h3>Note: For SQL and NoSQL,for some questions, we tried to think about same questions from two different perspective, by which it is not a single code convert, but rather a different thought to answer those questions.

# %% [markdown]
# <h3>Conclusion</h3>
# <ul>
#     <li>What topics are trending in my domain?</li>
# For SQL part, we did not use the twitter data, instead,we use the data scrapped from IMDB, given that the time we set is from 2006-2016, so we can see the trend in this period.
#     ![1524841290%281%29.jpg](attachment:1524841290%281%29.jpg)<br>
#     The most popular kind is Action,Adventure,Sci-Fi (all the time)
#
#
#    <li>What is the best time to post?</li>
# ![1524841621%281%29.jpg](attachment:1524841621%281%29.jpg)
# So we evaluate the sum of retweets and fav to see what time is the best time: around 22.30-23-40
#
# <li> What keywords/ hashtags should I add to my post?</li><br>
# ![1524841881%281%29.jpg](attachment:1524841881%281%29.jpg)
# By filtering the number of hashtags, we can see the most popular used hashtags in the domian, and users probably should add these hahtags.
#
# <li>Should I add an picture or url to my post?</li>
# By calculating the url numbers, we can see the results.![1524842296%281%29.jpg](attachment:1524842296%281%29.jpg)<br>
# 388/554
# 2803/3728
# 621/1000
# So the number reaches beyond the half, that's why url should post,we did not scrape the image, so we did not evaluate the images here
#
# <li> What’s my reach?</li>
# To answer this question, we calculate the average count of retweet to find out, and we especially calculated the number of different topic that used in tweet, but all about movie domain.<br>
# ![1524829737%281%29.jpg](attachment:1524829737%281%29.jpg)<br>
# As we can see in this part, 10,12,9 represent the separate topics: movie, Hollywood and casts, So the average value of retweet is around 10.
#
# <li>What are people saying about me (somebody)?</li>
# By filtering a user'name which probably appear in other 'user's text<br>
# ![1524838859%281%29.jpg](attachment:1524838859%281%29.jpg)<br>
# And the result is:![1524839231%281%29.jpg](attachment:1524839231%281%29.jpg)
#
#
# <li>How much influence to my posts have?</li>
# We mean to find out that in #hollywood, how influence tweets are?![1524839908%281%29.jpg](attachment:1524839908%281%29.jpg)
#
#
# <li>Who should I be following?</li>
# ![1524841021%281%29.jpg](attachment:1524841021%281%29.jpg)
# So we take three different parts: fav, retweets and folloers number to calculate
# <li>Should I follow somebody back?</li>
# ![1524841021%281%29.jpg](attachment:1524841021%281%29.jpg)
# So we take three different parts: fav, retweets and folloers number to calculate
#
#
# <li>What users post like me</li>![1524840748%281%29.jpg](attachment:1524840748%281%29.jpg)
# We use different keywords to filter the user_id and the text from the data to find all users in this hashtag page.
#
#
# <li>What posts are like mine?</li><br>
# ![1524840500%281%29.jpg](attachment:1524840500%281%29.jpg)
# We filter the hashtags in all tweets and we can find out the similar text
# <li>How viral are my posts?<li><br>
#    We targetd on a user_id which is 9.85E+17 to see the retweets number:
#     ![1524842903%281%29.jpg](attachment:1524842903%281%29.jpg)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </ul>

# %% [markdown]
# __[License](http://creativecommons.org/licenses/by-nc/4.0/)__
